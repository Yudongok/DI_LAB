# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from datasets import load_from_disk

ds = load_from_disk("/content/drive/MyDrive/DILAB/HJ/News_DILAB/train_tokenized")
print(ds)
print(ds.features)
print(ds[0])
print(ds[1])         # 첫 행
df = ds.to_pandas()  # 크면 메모리 주의
